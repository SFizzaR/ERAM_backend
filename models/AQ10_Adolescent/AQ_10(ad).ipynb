# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/FYP/Autism_Screening_Data_Combined.csv'
df = pd.read_csv(file_path)

# %%
df = df[(df['Age'] <= 15) & (df['Age'] >= 12)]

# %%
df['label'] = (df[['A1','A2','A3','A4','A5','A6','A7','A8','A9','A10']].sum(axis=1) >= 6).astype(int)

# %%
x = df.drop(['Class', 'Family_ASD', 'Jauundice', 'Sex', 'label'], axis=1)
y = df['label']
y.value_counts(normalize=True)
# Out:
# label
# 0    0.525926
# 1    0.474074
# Name: proportion, dtype: float64

# %%
print(x.shape)
print(y.shape)
# Out:
# (6075, 11)
# (6075,)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
print(le.classes_)
print(set(y))        # see all unique numeric classes
print(y[:10])        # see first few encoded labels
# Out:
# [0 1]
# {np.int64(0), np.int64(1)}
# [0 1 1 1 1 1 0 0 0 1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

# %%
print("X_train shape:", x_train.shape)
print("X_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (4860, 11)
# X_test shape: (1215, 11)
# y_train shape: (4860,)
# y_test shape: (1215,)

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Input(shape=(x_train.shape[1],)),   # 👈 explicit input layer
    layers.Dense(64, activation='relu'),       # 1st hidden layer (ReLU)
    layers.Dense(32, activation='relu'),       # 2nd hidden layer (ReLU)
    layers.Dense(1, activation='sigmoid')      # Output layer (classifier)
])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Stop training when val_loss doesn't improve for 5 epochs
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,          # wait 5 epochs after no improvement
    restore_best_weights=True  # rollback to best model
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(
    'best_model.keras',
    monitor='val_accuracy',
    save_best_only=True
)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    x_train, y_train,
    epochs=100,              # increase epochs safely
    batch_size=16,
    validation_split=0.2,
    verbose=1,
    callbacks=[early_stop, checkpoint]   # 👈 add EarlyStopping
)
# Out:
# Epoch 1/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7272 - loss: 0.5273 - val_accuracy: 0.8693 - val_loss: 0.3373
# Epoch 2/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8994 - loss: 0.2478 - val_accuracy: 0.9650 - val_loss: 0.1306
# Epoch 3/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9509 - loss: 0.1383 - val_accuracy: 0.9835 - val_loss: 0.0871
# Epoch 4/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9662 - loss: 0.1008 - val_accuracy: 0.9866 - val_loss: 0.0675
# Epoch 5/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9837 - loss: 0.0713 - val_accuracy: 0.9825 - val_loss: 0.0586
# Epoch 6/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9796 - loss: 0.0634 - val_accuracy: 0.9630 - val_loss: 0.0881
# Epoch 7/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9858 - loss: 0.0534 - val_accuracy: 0.9938 - val_loss: 0.0357
# Epoch 8/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9963 - loss: 0.0353 - val_accuracy: 0.9949 - val_loss: 0.0313
# Epoch 9/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9979 - loss: 0.0239 - val_accuracy: 0.9959 - val_loss: 0.0267
# Epoch 10/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9924 - loss: 0.0329 - val_accuracy: 0.9763 - val_loss: 0.0529
# Epoch 11/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9914 - loss: 0.0312 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 12/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9971 - loss: 0.0174 - val_accuracy: 1.0000 - val_loss: 0.0158
# Epoch 13/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9988 - loss: 0.0133 - val_accuracy: 0.9743 - val_loss: 0.0592
# Epoch 14/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9911 - loss: 0.0264 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 15/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0078
# Epoch 16/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9892 - loss: 0.0345 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 17/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 18/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 19/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 20/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 21/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 22/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 0.0026 - val_accuracy: 0.9969 - val_loss: 0.0131
# Epoch 23/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9935 - loss: 0.0206 - val_accuracy: 0.9846 - val_loss: 0.0331
# Epoch 24/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9987 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 25/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 26/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 27/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 28/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 29/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 30/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.4926e-04 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 31/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 7.7226e-04 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 32/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 7.0198e-04 - val_accuracy: 1.0000 - val_loss: 9.1533e-04
# Epoch 33/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.9815e-04 - val_accuracy: 1.0000 - val_loss: 9.3635e-04
# Epoch 34/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.7998e-04 - val_accuracy: 1.0000 - val_loss: 7.5060e-04
# Epoch 35/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.4628e-04 - val_accuracy: 1.0000 - val_loss: 7.1259e-04
# Epoch 36/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.0673e-04 - val_accuracy: 1.0000 - val_loss: 6.2524e-04
# Epoch 37/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.5355e-04 - val_accuracy: 1.0000 - val_loss: 5.3879e-04
# Epoch 38/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.4611e-04 - val_accuracy: 1.0000 - val_loss: 4.9605e-04
# Epoch 39/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.6710e-04 - val_accuracy: 1.0000 - val_loss: 4.4703e-04
# Epoch 40/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.1964e-04 - val_accuracy: 1.0000 - val_loss: 3.6455e-04
# Epoch 41/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.9315e-04 - val_accuracy: 1.0000 - val_loss: 3.2118e-04
# Epoch 42/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 1.8134e-04 - val_accuracy: 1.0000 - val_loss: 3.7424e-04
# Epoch 43/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.1901e-04 - val_accuracy: 1.0000 - val_loss: 2.4321e-04
# Epoch 44/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.4581e-04 - val_accuracy: 1.0000 - val_loss: 2.4211e-04
# Epoch 45/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.1709e-04 - val_accuracy: 1.0000 - val_loss: 2.2521e-04
# Epoch 46/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9917 - loss: 0.0514 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 47/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9891 - loss: 0.0239 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 48/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 49/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 50/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.9115e-04 - val_accuracy: 1.0000 - val_loss: 8.5755e-04

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.8962e-04
# Test Accuracy: 1.0000

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

y_pred = (model.predict(x_test) > 0.5).astype(int)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       639
#            1       1.00      1.00      1.00       576
#
#     accuracy                           1.00      1215
#    macro avg       1.00      1.00      1.00      1215
# weighted avg       1.00      1.00      1.00      1215
#
# [[639   0]
#  [  0 576]]

# %%
# Save model
model.save('/content/drive/MyDrive/FYP/adolescent_model.keras')

# Save label encoder
import joblib
joblib.dump(le, '/content/drive/MyDrive/FYP/label_encoder.pkl')
# Out:
# ['/content/drive/MyDrive/FYP/label_encoder.pkl']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Get predictions
y_pred = model.predict(x_test)
y_pred_classes = (y_pred > 0.5).astype("int32")  # Threshold at 0.5

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

# Plot
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Non-Autistic', 'Autistic'],
            yticklabels=['Non-Autistic', 'Autistic'])
plt.title('Confusion Matrix - Adolescent Autism Model')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Save to Drive
plt.savefig('/content/drive/MyDrive/FYP/adolescent_confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
