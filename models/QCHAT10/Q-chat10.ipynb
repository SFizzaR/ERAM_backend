# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/FYP/Toddler Autism dataset July 2018.csv'
df = pd.read_csv(file_path)

# %%
# Convert age from months to years
df['Age'] = df['Age_Mons'] / 12

# Drop unnecessary columns
df = df.drop(
    ['Case_No', 'Age_Mons', 'Sex', 'Qchat-10-Score', 'Ethnicity',
     'Jaundice', 'Family_mem_with_ASD', 'Who completed the test'],
    axis=1
)

# Drop duplicate rows (just in case)
df = df.drop_duplicates()

# (Optional) Check if duplicates are gone
print(f"Duplicates remaining: {df.duplicated().sum()}")
# Out:
# Duplicates remaining: 0

# %%
df.groupby('Class/ASD Traits ').mean(numeric_only=True)
# Out:
#                          A1        A2        A3        A4        A5        A6  \
# Class/ASD Traits
# No                 0.244019  0.124402  0.119617  0.177033  0.138756  0.205742
# Yes                0.698113  0.550600  0.493997  0.653516  0.667238  0.725557
#
#                          A7        A8        A9       A10       Age
# Class/ASD Traits
# No                 0.311005  0.167464  0.086124  0.444976  2.245215
# Yes                0.809605  0.557461  0.655232  0.617496  2.325186

# %%
x = df.drop(['Class/ASD Traits '], axis=1)
y = df['Class/ASD Traits ']
y.value_counts(normalize=True)
# Out:
# Class/ASD Traits
# Yes    0.736111
# No     0.263889
# Name: proportion, dtype: float64

# %%
print(x.shape)
print(y.shape)
# Out:
# (792, 11)
# (792,)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
print(le.classes_)
print(set(y))        # see all unique numeric classes
print(y[:10])        # see first few encoded labels
# Out:
# ['No' 'Yes']
# {np.int64(0), np.int64(1)}
# [0 1 1 1 1 1 1 1 0 1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

# %%
print("X_train shape:", x_train.shape)
print("X_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (633, 11)
# X_test shape: (159, 11)
# y_train shape: (633,)
# y_test shape: (159,)

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Input(shape=(x_train.shape[1],)),   # 👈 explicit input layer
    layers.Dense(64, activation='relu'),       # 1st hidden layer (ReLU)
    layers.Dense(32, activation='relu'),       # 2nd hidden layer (ReLU)
    layers.Dense(1, activation='sigmoid')      # Output layer (classifier)
])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Stop training when val_loss doesn't improve for 5 epochs
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,          # wait 5 epochs after no improvement
    restore_best_weights=True  # rollback to best model
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(
    'best_model.keras',
    monitor='val_accuracy',
    save_best_only=True
)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    x_train, y_train,
    epochs=100,              # increase epochs safely
    batch_size=16,
    validation_split=0.2,
    verbose=1,
    callbacks=[early_stop, checkpoint]   # 👈 add EarlyStopping
)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6294 - loss: 0.6027 - val_accuracy: 0.7087 - val_loss: 0.4334
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7514 - loss: 0.4130 - val_accuracy: 0.8346 - val_loss: 0.3131
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8561 - loss: 0.2948 - val_accuracy: 0.9213 - val_loss: 0.2328
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9105 - loss: 0.2270 - val_accuracy: 0.9291 - val_loss: 0.1880
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9019 - loss: 0.2153 - val_accuracy: 0.9449 - val_loss: 0.1610
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9509 - loss: 0.1660 - val_accuracy: 0.9685 - val_loss: 0.1426
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9484 - loss: 0.1440 - val_accuracy: 0.9528 - val_loss: 0.1361
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9565 - loss: 0.1280 - val_accuracy: 0.9685 - val_loss: 0.1191
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9658 - loss: 0.1082 - val_accuracy: 0.9606 - val_loss: 0.0990
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9801 - loss: 0.1046 - val_accuracy: 0.9685 - val_loss: 0.0997
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9708 - loss: 0.0970 - val_accuracy: 0.9685 - val_loss: 0.0911
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9809 - loss: 0.0824 - val_accuracy: 0.9685 - val_loss: 0.0787
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9810 - loss: 0.0705 - val_accuracy: 0.9685 - val_loss: 0.0770
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9842 - loss: 0.0737 - val_accuracy: 0.9685 - val_loss: 0.0728
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9909 - loss: 0.0593 - val_accuracy: 0.9764 - val_loss: 0.0658
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9962 - loss: 0.0495 - val_accuracy: 0.9764 - val_loss: 0.0590
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9855 - loss: 0.0612 - val_accuracy: 0.9843 - val_loss: 0.0548
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9984 - loss: 0.0386 - val_accuracy: 0.9606 - val_loss: 0.0701
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9992 - loss: 0.0362 - val_accuracy: 0.9921 - val_loss: 0.0533
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0319 - val_accuracy: 0.9921 - val_loss: 0.0501
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0240 - val_accuracy: 0.9921 - val_loss: 0.0489
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0262 - val_accuracy: 0.9921 - val_loss: 0.0475
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0235 - val_accuracy: 0.9843 - val_loss: 0.0464
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0227 - val_accuracy: 0.9921 - val_loss: 0.0404
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0207 - val_accuracy: 0.9921 - val_loss: 0.0400
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 0.9921 - val_loss: 0.0386
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0180 - val_accuracy: 0.9764 - val_loss: 0.0497
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0161 - val_accuracy: 0.9921 - val_loss: 0.0352
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 0.9843 - val_loss: 0.0372
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 0.9843 - val_loss: 0.0378
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.9843 - val_loss: 0.0378
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.9921 - val_loss: 0.0293
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.9921 - val_loss: 0.0320
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.9843 - val_loss: 0.0320
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9843 - val_loss: 0.0304
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9921 - val_loss: 0.0279
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9921 - val_loss: 0.0252
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9921 - val_loss: 0.0259
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9921 - val_loss: 0.0247
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9921 - val_loss: 0.0236
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9921 - val_loss: 0.0213
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9921 - val_loss: 0.0244
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9921 - val_loss: 0.0209
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9921 - val_loss: 0.0237
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9921 - val_loss: 0.0187
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9921 - val_loss: 0.0216
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9921 - val_loss: 0.0197
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9921 - val_loss: 0.0203
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9921 - val_loss: 0.0188
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9921 - val_loss: 0.0182
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9921 - val_loss: 0.0180
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9921 - val_loss: 0.0158
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9921 - val_loss: 0.0164
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0144
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9921 - val_loss: 0.0157
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9921 - val_loss: 0.0153
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9921 - val_loss: 0.0143
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9921 - val_loss: 0.0152
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0131
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0120
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0131
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0128
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0129
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0120
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0108
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 9.4727e-04 - val_accuracy: 1.0000 - val_loss: 0.0100
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.0228e-04 - val_accuracy: 1.0000 - val_loss: 0.0109
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.8642e-04 - val_accuracy: 1.0000 - val_loss: 0.0103
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.2427e-04 - val_accuracy: 1.0000 - val_loss: 0.0100
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.0638e-04 - val_accuracy: 1.0000 - val_loss: 0.0093
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 7.7773e-04 - val_accuracy: 1.0000 - val_loss: 0.0108
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 8.2597e-04 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0092
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.9197e-04 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.6148e-04 - val_accuracy: 1.0000 - val_loss: 0.0089
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.4166e-04 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.9587e-04 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.8007e-04 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.2313e-04 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.4934e-04 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.5916e-04 - val_accuracy: 1.0000 - val_loss: 0.0078
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.8716e-04 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.8868e-04 - val_accuracy: 1.0000 - val_loss: 0.0081
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.3158e-04 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 4.0966e-04 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.7702e-04 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.8144e-04 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.5131e-04 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.5172e-04 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.9811e-04 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 3.3536e-04 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.5360e-04 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.4232e-04 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.9103e-04 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.7916e-04 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 3.1614e-04 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.7675e-04 - val_accuracy: 1.0000 - val_loss: 0.0059

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0019
# Test Accuracy: 1.0000

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

y_pred = (model.predict(x_test) > 0.5).astype(int)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        42
#            1       1.00      1.00      1.00       117
#
#     accuracy                           1.00       159
#    macro avg       1.00      1.00      1.00       159
# weighted avg       1.00      1.00      1.00       159
#
# [[ 42   0]
#  [  0 117]]

# %%
set_train = set(map(tuple, x_train.values))
set_test = set(map(tuple, x_test.values))
print("Overlap:", len(set_train.intersection(set_test)))
len(set(x_train.index).intersection(set(x_test.index)))
# Out:
# Overlap: 0
# 0

# %%
import numpy as np
import pandas as pd

# Compute the "manual" score like the QChat-10 rule
df["manual_score"] = df[["A1","A2","A3","A4","A5","A6","A7","A8","A9","A10"]].sum(axis=1)

# Predict using your model
preds = model.predict(x)
pred_labels = (preds > 0.5).astype(int).flatten()

# Compare manual rule (>3 means autistic) vs model prediction
rule_labels = (df["manual_score"] > 3).astype(int)

agreement = np.mean(rule_labels == pred_labels)
print(f"Agreement between QChat rule and model: {agreement:.3f}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Agreement between QChat rule and model: 1.000

# %%
print(model.evaluate(x_train, y_train))
print(model.evaluate(x_test, y_test))
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.0996e-04
# [0.001417785999365151, 1.0]
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0019
# [0.0026087716687470675, 1.0]

# %%
# Save model
model.save('/content/drive/MyDrive/FYP/toddler_model.keras')

# Save label encoder
import joblib
joblib.dump(le, '/content/drive/MyDrive/FYP/label_encoder_QCHAT10.pkl')
# Out:
# ['/content/drive/MyDrive/FYP/label_encoder_QCHAT10.pkl']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Get predictions
y_pred = model.predict(x_test)
y_pred_classes = (y_pred > 0.5).astype("int32")  # Threshold at 0.5

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

# Plot
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Non-Autistic', 'Autistic'],
            yticklabels=['Non-Autistic', 'Autistic'])
plt.title('Confusion Matrix - Adolescent Autism Model')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Save to Drive
plt.savefig('/content/drive/MyDrive/FYP/adolescent_confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
